# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %%
from konlpy.tag import Okt
import random

okt = Okt()
okt.morphs('우리 디자인 교육관을 가지 않고 사회교육관으로 가고 싶다')
# Out:
# ['우리',
#  '디자인',
#  '교육',
#  '관',
#  '을',
#  '가지',
#  '않고',
#  '사',
#  '회교',
#  '육',
#  '관',
#  '으로',
#  '가고',
#  '싶다']

# %%
def remove_duplicates(input_list):
    return list(set(map(str, input_list)))
# 예시 입력 리스트
'''
places = [
    "한양대학교 서울캠퍼스 백남음악관", "한양대학교 서울캠퍼스 HIT", "한양대학교 서울캠퍼스 학생회관",
    "한양대학교 서울캠퍼스 올림픽체육관", "한양대학교 ERICA캠퍼스 셔틀콕 정류장",
    "한양대학교 ERICA캠퍼스 제1공학관", "한양대학교 ERICA캠퍼스 제2공학관",
    "한양대학교 ERICA캠퍼스 제3공학관", "한양대학교 ERICA캠퍼스 제4공학관",
    "한양대학교 ERICA캠퍼스 제5공학관", "한양대학교 ERICA캠퍼스 제2과학기술관",
    "한양대학교 ERICA캠퍼스 제1과학기술관", "한양대학교 ERICA캠퍼스 경상관",
    "한양대학교 ERICA캠퍼스 건축디자인관", "한양대학교 ERICA캠퍼스 학생회관",
    "한양대학교 ERICA캠퍼스 학생복지관", "한양대학교 ERICA캠퍼스 창의인재원",
    "한양대학교 ERICA캠퍼스 행복관", "한양대학교 ERICA캠퍼스 창업보육센터",
    "한양대학교 ERICA캠퍼스 디자인교육관", "한양대학교 ERICA캠퍼스 사회교육관",
    "한양대학교 생활과학관 6층 FabLab", "한양대학교 서울캠퍼스 제1공학관",
    "한양대학교 서울캠퍼스 신소재공학관", "한양대학교 서울캠퍼스 과학기술관",
    "한양대학교 서울캠퍼스 사범대학본관", "한양대학교 서울캠퍼스 사범대학별관",
    "한양대학교 서울캠퍼스 인문관", "한양대학교 서울캠퍼스 제1음악관", "한양대학교 서울캠퍼스 제2음악관",
    "한양대학교 서울캠퍼스 사회과학관", "한양대학교 서울캠퍼스 국제관", "한양대학교 미래교육관",
    "한양대학교 서울캠퍼스 정보통신관 ITBT관", "한양대학교 서울캠퍼스 ITBT관", "서울대학교 관악캠퍼스 호암교수회관",
    "서울대학교 관악캠퍼스 중앙도서관", "서울대학교 관악캠퍼스 건설환경종합연구소",
    "서울대학교 관악캠퍼스 공대간이식당", "서울대학교 관악캠퍼스 학생회관", "서울대학교 관악캠퍼스 제2공학관",
    "서울대학교 관악캠퍼스 신공학관", "서울대학교 관악캠퍼스 제1공학관", "서울대학교 관악캠퍼스 공학관실험동",
    "서울대학교 관악캠퍼스 사범대학", "서울대학교 관악캠퍼스 사범대학과학교육관", "서울대학교 관악캠퍼스 기초사범교육협력센터",
    "서울대학교 관악캠퍼스 학생회관", "서울대학교 관악캠퍼스 광학물성실험실", "서울대학교 관악캠퍼스 행정관",
    "서울대학교 관악캠퍼스 행정대학원", "서울대학교 관악캠퍼스 국제스포츠행정가양성사업단", "서울대학교 관악캠퍼스 대학행정교육원",
    "서울대학교 관악캠퍼스 두산인문관", "서울대학교 관악캠퍼스 음대예술관 콘서트홀", "서울대학교 관악캠퍼스 예술관",
    "서울대학교 관악캠퍼스 사회과학관", "서울대학교 관악캠퍼스 BK국제관", "서울대학교 관악캠퍼스 롯데국제관",
    "서울대학교 관악캠퍼스 대림국제관", "서울대학교 BK국제관 관리실", "서울대학교 관악캠퍼스 사범대학과학교육관",
    "서울대학교 관악캠퍼스 반도체공동연구소교육관", "연세대학교 신촌캠퍼스 노천극장", "연세대학교 신촌캠퍼스 이윤재관",
    "연세대학교 신촌캠퍼스 새천년관", "연세대학교 치과대학", "연세대학교 신촌캠퍼스 언어연구교육원한국어",
    "연세대학교 신촌캠퍼스 제1공학관", "연세대학교 신촌캠퍼스 제4공학관", "연세대학교 신촌캠퍼스 제2공학관",
    "연세대학교 신촌캠퍼스 제3공학관", "연세대학교 신촌캠퍼스 체육관", "연세대학교 신촌캠퍼스 의학도서관",
    "연세대학교 신촌캠퍼스 중앙도서관", "연세대학교 국제캠퍼스 지혜관A", "연세대학교 신촌캠퍼스 학생회관",
    "연세대학교 신촌캠퍼스 대학원학생회관", "연세대학교 미래캠퍼스 학생회관", "연세대학교 신촌캠퍼스 제4공학관",
    "연세대학교 신촌캠퍼스 음악관 B", "연세대학교 신촌캠퍼스 음악관 A", "연세대학교 의과대학",
    "연세대학교 미래캠퍼스 창업보육센터", "연세대학교 미래캠퍼스 장애인창업보육센터", "연세대학교 신촌캠퍼스 체육교육관",
    "연세대학교 신촌캠퍼스 GS칼텍스산학협력관", "고려대학교 서울캠퍼스 화정체육관", "고려대학교 서울캠퍼스 녹지운동장",
    "고려대학교 서울캠퍼스 SK미래관", "고려대학교 서울캠퍼스 교우회관", "고려대학교 서울캠퍼스 과학도서관",
    "고려대학교 서울캠퍼스 신공학관", "고려대학교 서울캠퍼스 공학관", "한성대학교 공학관 A동",
    "한성대학교 공학관 B동", "서울대학교 사범대학부설고등학교 축구장", "고려대학교 서울캠퍼스 사범대학신관",
    "고려대학교 서울캠퍼스 화정체육관", "한성대학교 체육관", "고려대학교 서울캠퍼스 학생회관",
    "고려대학교 서울캠퍼스 애기능학생회관", "성신여자대학교 학생회관", "동덕여자대학교 학생회관",
    "성신여자대학교 행정관", "동덕여자대학교 인문관", "성신여자대학교 음악관", "동덕여자대학교 율동기념음악관",
    "성신여자대학교 스마트혁신창업센터", "고려대학교 서울캠퍼스 생명과학관동관", "고려대학교 서울캠퍼스 국제관",
    "고려대학교 서울캠퍼스 운초우선교육관", "고려대학교 서울캠퍼스 한국어교육관", "고려대학교 서울캠퍼스 우정정보관",
    "서강대학교 정하상관", "서강대학교 체육관", "서강대학교 베르크만스우정원", "서강대학교 본관",
    "서강대학교 종합봉사실", "이화여자대학교 조형예술관 C동", "이화여자대학교 조형예술관 A동",
    "이화여자대학교 음악관", "성균관대학교 인문사회과학캠퍼스 600주년기념관", "성균관대학교 인문사회과학캠퍼스 법학관",
    "성균관대학교 인문사회과학캠퍼스 수선관별관", "성균관대학교 인문사회과학캠퍼스 경영관", "성균관대학교 인문사회과학캠퍼스 학술정보관",
    "성균관대학교 자연과학캠퍼스 제2공학관", "성균관대학교 자연과학캠퍼스 생명공학관", "성균관대학교 자연과학캠퍼스 제약기술관",
    "성균관대학교 자연과학캠퍼스 체육관", "성균관대학교 도봉선수촌실내체육관", "성균관대학교 인문사회과학캠퍼스 학생회관",
    "성균관대학교 자연과학캠퍼스 학생회관", "성균관대학교 퇴계인문관", "홍익대학교 서울캠퍼스 홍문관",
    "홍익대학교 서울캠퍼스 제2기숙사", "홍익대학교 서울캠퍼스 인문사회관C동", "홍익대학교 서울캠퍼스 문헌관",
    "홍익대학교 서울캠퍼스와우관", "홍익대학교 서울캠퍼스 제2공학관", "홍익대학교 서울캠퍼스 제1공학관",
    "홍익대학교 서울캠퍼스 제4공학관", "홍익대학교 서울캠퍼스 제3공학관", "홍익대학교 서울캠퍼스 체육관",
    "홍익대학교 서울캠퍼스 학생회관", "홍익대학교 서울캠퍼스 제2기숙사", "중앙대학교 서울캠퍼스 309관 블루미르홀 기숙사",
    "중앙대학교 서울캠퍼스 법학관", "중앙대학교 서울캠퍼스 308관 블루미르홀 기숙사", "중앙대학교 서울캠퍼스 서라벌홀",
    "중앙대학교 서울캠퍼스 약학대학R&D센터", "중앙대학교 서울캠퍼스 제2공학관", "중앙대학교 서울캠퍼스 창의ICT공학관",
    "중앙대학교 서울캠퍼스 체육관", "중앙대학교 서울캠퍼스 학생회관", "숭실대학교 학생회관", "숭실대학교 교육관",
    "숭실대학교 산학협력단", "중앙대학교 서울캠퍼스 창업보육관", "경희대학교 서울캠퍼스 평화의전당", "경희대학교 서울캠퍼스 청운관",
    "경희대학교 캠퍼스타운 삼의원창업센터", "경희대학교 서울캠퍼스 오비스홀", "경희대학교 서울캠퍼스 학생회관",
    "서울시립대학교 시대융합관", "서울시립대학교 제2공학관", "서울시립대학교 건설공학관", "서울시립대학교 과학기술관",
    "서울시립대학교 학생회관", "한국외국어대학교 서울캠퍼스 학생회관 및기숙사", "동덕여자대학교 인문관",
    "서울시립대학교 음악관", "동덕여자대학교 율동기념음악관", "한국외국어대학교 서울캠퍼스 사회과학관",
    "서울시립대학교 인문학관", "한국외국어대학교 서울캠퍼스 국제관", "건국대학교 서울캠퍼스 상허연구관",
    "건국대학교 서울캠퍼스 산학협동관", "건국대학교 서울캠퍼스 예술디자인대학", "건국대학교 서울캠퍼스 제1학생회관",
    "건국대학교 서울캠퍼스 공학관", "건국대학교 서울캠퍼스 신공학관", "건국대학교 서울캠퍼스 공학관별관X-Space",
    "건국대학교 서울캠퍼스 교육과학관", "건국대학교 서울캠퍼스 제1학생회관", "건국대학교 서울캠퍼스 제2학생회관",
    "건국대학교 서울캠퍼스 행정관", "건국대학교 서울캠퍼스 경영관", "건국대학교 서울캠퍼스 창의관",
    "건국대학교 서울캠퍼스 인문학관", "건국대학교 서울캠퍼스 인문학관강의동", "건국대학교 서울캠퍼스 생명과학관",
    "건국대학교 서울캠퍼스 동물생명과학관", "건국대학교 서울캠퍼스 생명과학관부속동", "동국대학교 서울캠퍼스 혜화관",
    "동국대학교 서울캠퍼스 본관", "동국대학교 서울캠퍼스 이해랑예술극장", "동국대학교 서울캠퍼스 학림관",
    "동국대학교 서울캠퍼스 상록원", "동국대학교 서울캠퍼스 신공학관", "동국대학교 서울캠퍼스 체육관",
    "동국대학교 서울캠퍼스 학생회관", "동국대학교 서울캠퍼스 남산학사", "서울예술대학교 남산캠퍼스 예술관",
    "숭의여자대학교 숭의체육관", "한국예술종합학교 석관동캠퍼스 연극원"
]
places_added = ["전자정보공과대학", "생명과학대학", "사회과학대학", "기술경영융합대학", "의과대학", "치과대학", "학생회관",
    "정보전산원", "국제관", "신소재공학관", "화정체육관", "녹지운동장", "공대간이식당", "학술정보관", "산학협동관",
    "예술디자인대학", "산학협력단", "산학협력단", "산학협력단", "산학협력단", "산학협력단", "산학협력단",
    "창의ICT공학관", "박물관", "율동기념음악관", "법학관", "체육관", "학림관", "남산학사", "남산학사",
    "남산학사", "성곡기념회관", "이윤재관", "노천극장", "실내체육관", "블루미르홀", "행정대학원", "학생회관",
    "행정관", "복지관", "복지관", "한국방송통신대학교", "인문학관", "중앙도서관", "신공학관", "신공학관",
    "행정관", "행정관", "행정관", "경영관", "창의관", "창의관강의동", "인문학관", "생명과학관", "생명과학관부속동",
    "체육관", "학생회관", "남산학사", "연극원", "학술정보관", "제일공학관", "제이공학관", "제삼공학관", "제사공학관", "제1공학관", "제2공학관","제3공학관","제4공학관","제5공학관","제 1공학관", "제 2공학관","제 3공학관","제 4공학관","제 5공학관", "기숙사"]
places.extend(places_added)
'''

places = ["학술정보관", "제일공학관", "제이공학관", "제삼공학관", "제사공학관", "제1공학관", "제2공학관","제3공학관","제4공학관","제5공학관","제 1공학관", "제 2공학관","제 3공학관","제 4공학관","제 5공학관", "기숙사"]
library = []

for place in places:
    words = okt.morphs(place)
    if not words:  # 빈 리스트인 경우
        continue

    for j in range(len(words)):
      library.append(words[j])


library = remove_duplicates(library)

for lib in library:
  print(lib)

#library 만들 수 있음


'''
내수어린이공원
'''

# %%
okt.morphs("나는 한국대학교 자연캠퍼스에 갈거야")
# Out:
# ['나', '는', '한국', '대학교', '자연', '캠퍼스', '에', '갈거야']

# %%
import json
import pandas as pd

f = open("./dataset.txt", "w")
entities = []
#library.append(library_added)

i = 45988


def tagging(sentence):

  okt = Okt()
  words = okt.morphs(sentence)
  flag = 0
  preprocess_word = []
  for word in words:
    if '을' in word or '를' in word or'로' in word or '으로' in word or '에' in word:
      for char in word:
        preprocess_word.append(char)
    else :
      preprocess_word.append(word)

  tagged_result = []

  for word in preprocess_word:
      if (word in library) and flag == 0:
        tagged_result.append((word, 'B_LOC_pos'))
        #entities.append(word)
        print( str(i) + "\t" + word + "\t" +"B_LOC_pos")
        f.write(str(i) + "\t" + word + "\t" + "B_LOC_pos" + "\n")
        flag = 1

      elif word in library:
        tagged_result.append((word, 'I_LOC_pos'))
        #entities.append(word)
        print( str(i) + "\t"  + word + "\t" +"I_LOC_pos")
        f.write(str(i) + "\t" + word + "\t" +"I_LOC_pos" + "\n")

      else:
        tagged_result.append((word, '0'))
        #entities.append(word)
        print( str(i) + "\t"  + word + "\t"  +"O")
        f.write(str(i) + "\t" + word + "\t" + "O"+ "\n")


  print("\n")
  f.write("\n\n")
  return tagged_result

# sentence = "우리 디자인 교육관를 가지 않고 사회교육관으로 가고 싶다"

# result = tagging(sentence)

# %%
def tagging_1(sentence):

  okt = Okt()
  words = okt.morphs(sentence)
  flag = 0
  preprocess_word = []

  for word in words:
    if '을' in word or '를' in word or '로' in word or '으로' in word or '에' in word:
      for char in word:
        preprocess_word.append(char)
    else :
      preprocess_word.append(word)
  tagged_result = []
  for word in preprocess_word:
      if (word in library) and flag == 0:
        tagged_result.append((word, 'B_LOC'))
        #entities.append(word)
        print( str(i) + "\t" + word + "\t" +"B_LOC_neg")
        f.write(str(i) + "\t" + word + "\t" + "B_LOC_neg" + "\n")
        flag = 1

      elif (word in library) and flag == 1:
        tagged_result.append((word, 'I_LOC'))
        #entities.append(word)
        print( str(i) + "\t"  + word + "\t" +"I_LOC_neg")
        f.write(str(i) + "\t" + word + "\t" +"I_LOC_neg" + "\n")

      elif (word in library) and flag == 2:
        tagged_result.append((word, 'I_LOC'))
            #entities.append(word)
        print( str(i) + "\t"  + word + "\t" +"B_LOC_pos")
        f.write(str(i) + "\t" + word + "\t" +"B_LOC_pos" + "\n")
        flag = 3

      elif (word in library) and flag ==3:
        tagged_result.append((word, 'I_LOC'))
            #entities.append(word)
        print( str(i) + "\t"  + word + "\t" +"I_LOC_pos")
        f.write(str(i) + "\t" + word + "\t" +"I_LOC_pos" + "\n")

      elif flag == 1 or flag == 2:
        tagged_result.append((word, '0'))
        #entities.append(word)
        print( str(i) + "\t"  + word + "\t"  +"O")
        f.write(str(i) + "\t" + word + "\t" + "O"+ "\n")
        flag = 2


      else:
        tagged_result.append((word, '0'))
        #entities.append(word)
        print( str(i) + "\t"  + word + "\t"  +"O")
        f.write(str(i) + "\t" + word + "\t" + "O"+ "\n")
        flag = 0
  print("\n")
  f.write("\n\n")

# %%
person = ['','나는', '내가', '나', '우리는', '우리'] # 6개
#place = ['본관', '학생복지관', '학생회관', '제2공학관', '건축디자인관', '초대형구조실험동','풍환경실험관', '수리실험동', '디자인문화관', '디자인교육관','디자인교육관', '디자인연구관','스마트건축관', '경상관', '국제문화관', '사회교육관','학군단', '언론정보관', '제1과학기술관', '컨퍼런스홀','제2과학기술관']
#place.extend(['한양 맞춤의약연구원', '제1학술관', '제1공학관','폐수처리장관리동', '제3공학관', '제4공학관','제5공학관','셔틀콕','에리카컨벤션센터','창업보육센터', '약학관','동물실험동','학연산클러스터지원센터','산학연협력관','포장 가속실험동','퓨전전기기술응용연구센터','비엠알센터','학술정보관','체육관','실용음악관', '대운동장', '테니스장', '창의관', '인재관', '행복관', '창의인재원 교육관'])
#place.extend(['음식남녀', '매화반점본점', '이스탄불그릴', '멕시코식당', '하오차이', '금성식당', '칙피스가로수길점', '나무호텔', '그랜드호텔서울', '성애병원', '천안충무병원', '서울명병원', '경기도의료원포천병원', '제인병원', '우리병원', '부평세림병원', '코키아병원', '병원', '한림대학교동탄성심병원응급실', '우리효사랑요양병원', '경기도립의료원파주병원', '동방학교', '쉐마학교', '신나는학교', '안양해솔학교', '소명나무학교', '인천성동학교', '서울경운학교', '한길학교', '아름다운학교', '월암근린공원', '배밭공원', '명달공원', '원적산공원에서나비공원올래길', '호반써밋차아파트', '삼송호반베르디움단지아파트', '한빛아파트', '홍제원현대아파트', '한아름한국아파트', '한일타운쌍용아파트', '창동태영데시앙아파트', '대주피오레단지아파트', '래미안엘파인아파트', '진로아파트관리사무실', '우면파라곤아파트', '이매한신아파트', '신영통현대아파트단지', '수지건영아파트입주자대표회의', '마곡수명산파크단지아파트', '오류동신동아아파트', '무궁화마을금호아파트', '우찬아파트', '인천건물매매', '상가주택상가주택매매서울인천경기상가주택상가건물매매', '일반건물', '형제건물', '빌라건물', '빌라건물', '하이종합건물관리', '건물종합관리', '로인건물종합관리', '주집합건물과사람들', '한국건물관리센터', '건물관리대행도원', '지성종합건물관리주', '소래포구종합어시장신축건물', '건물관리', '한국건물관리센터', '주한결건물관리', '빌라건물', '용현종중건물', '한국건물관리주', '그랜드호텔서울', '경기도의료원포천병원', '삼성병원본관', '경기도립의료원파주병원', '경기도의료원이천병원', '영등포병원', '성모윌병원', '힘찬병원', '동두천제생병원', '메디인병원', '희명병원별관진료센터', '여명학교', '청운공원', '내수어린이공원', '애플이마트청계천점'])
"을 를 에 "

sentence_pos = ["","에 가고 싶어" , "에 갈거야", "에 갈 예정이야", " 갈래", "에 갈래", "에 가고 싶습니다", " 가고 싶습니다", " 가고 싶어요", "에 가고 싶어요"," 가도 되나요", " 가도 될까요","을 가도 될까요", " 가게 해줘", "으로 가고 싶다", "으로 가고 싶습니다", "가게 해줘", "으로 가게 해줘"] # 16개
sentence_neg_1 = [" 말고 ", " 가지 않고 ", " 경유하지 않고 ", " 안 가고 ", " 피해서 ", " 가지 않고 " ,"을 가지 않고 "]
sentence_neg_2 = [" 안 갈거야", " 안갈거야", " 피할거야","는 경유하지 않을겁니다"," 경유하지 않을거야", " 지나치지 않을거야", "을 지나치지 않을겁니다", " 경유하지 않을겁니다"]
i = 45989
j = 0



for _ in person:
    for _ in places:
        for _ in sentence_pos:
          subject = random.choice(person)
          object = random.choice(places)
          verb = random.choice(sentence_pos)
          string = subject + " " + object + verb
          result = tagging(string)
          i = i + 1
          #print(result)
          with open("./dataset.json", "w", encoding = "utf-8") as json_file:
                json.dump(result, json_file, ensure_ascii=False, )
          if (i == 47000):
            break
        if (i == 47000):
          break
    if (i == 47000):
      break

# %%
for subject in person:
  for a in range(0,5) :
    for verb_1 in sentence_neg_1:
      for b in range(0,5):
        for verb_2 in sentence_pos:
          object_1 = random.choice(places)
          object_2 = random.choice(places)
          string = subject + " " + object_1 + verb_1 + object_2 + verb_2
          result = tagging_1(string)
          i = i + 1
            #print(result)
          with open("./dataset.json", "w", encoding = "utf-8") as json_file:
            json.dump(result, json_file, ensure_ascii=False, )
          if (i == 48000):
            break
        if (i == 48000):
          break
      if (i == 48000):
        break
    if (i == 48000):
      break
  if (i == 48000):
      break

# %%
def tagging_3(sentence):

  okt = Okt()
  words = okt.morphs(sentence)
  flag = 0
  preprocess_word = []

  for word in words:
    if '을' in word or '를' in word or '로' in word or '으로' in word or '에' in word:
      for char in word:
        preprocess_word.append(char)
    else :
      preprocess_word.append(word)
  tagged_result = []
  for word in preprocess_word:
      if (word in library) and flag == 0:
        tagged_result.append((word, 'B_LOC'))
        #entities.append(word)
        print( str(i) + "\t" + word + "\t" +"B_LOC_pos")
        f.write(str(i) + "\t" + word + "\t" + "B_LOC_pos" + "\n")
        flag = 1

      elif (word in library) and flag == 1:
        tagged_result.append((word, 'I_LOC'))
        #entities.append(word)
        print( str(i) + "\t"  + word + "\t" +"I_LOC_pos")
        f.write(str(i) + "\t" + word + "\t" +"I_LOC_pos" + "\n")

      elif (word in library) and flag == 2:
        tagged_result.append((word, 'I_LOC'))
            #entities.append(word)
        print( str(i) + "\t"  + word + "\t" +"B_LOC_neg")
        f.write(str(i) + "\t" + word + "\t" +"B_LOC_neg" + "\n")
        flag = 3

      elif (word in library) and flag ==3:
        tagged_result.append((word, 'I_LOC'))
            #entities.append(word)
        print( str(i) + "\t"  + word + "\t" +"I_LOC_neg")
        f.write(str(i) + "\t" + word + "\t" +"I_LOC_neg" + "\n")

      elif flag == 1 or flag == 2:
        tagged_result.append((word, '0'))
        #entities.append(word)
        print( str(i) + "\t"  + word + "\t"  +"O")
        f.write(str(i) + "\t" + word + "\t" + "O"+ "\n")
        flag = 2


      else:
        tagged_result.append((word, '0'))
        #entities.append(word)
        print( str(i) + "\t"  + word + "\t"  +"O")
        f.write(str(i) + "\t" + word + "\t" + "O"+ "\n")
        flag = 0
  print("\n")
  f.write("\n\n")

# %%
for subject in person:
  for a in range(0,5):
    for verb_1 in sentence_pos:
      for b in range(0,5):
        for verb_2 in sentence_neg_2:
          object_1 = random.choice(places)
          object_2 = random.choice(places)
          string = subject + " " + object_1 + verb_1 + object_2 + verb_2
          result = tagging_3(string)
          i = i + 1
            #print(result)
          with open("./dataset.json", "w", encoding = "utf-8") as json_file:
            json.dump(result, json_file, ensure_ascii=False, )
          if (i == 49000):
            break
        if (i == 49000):
          break
      if (i == 49000):
        break
    if (i == 49000):
      break
  if (i == 49000):
    break
